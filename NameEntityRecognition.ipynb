# %%
corpus="""On 15 August 2025 at 10:30 AM, Rahul Sharma arrived in Bengaluru to attend a strategy meeting at Infosys headquarters. During the presentation, the finance team reported that quarterly revenue had grown by 12 percent, with marketing expenses capped at ₹50,00,000, and noted that the company’s partnership with TCS had contributed significantly to this increase."""

# %%
import nltk
words=nltk.word_tokenize(corpus)

# %%
tag_elements=nltk.pos_tag(words)

# %%
nltk.download('maxent_ne_chunker',download_dir=r"D:\nltk_data")
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to D:\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# True

# %%
nltk.download('words',download_dir=r"D:\nltk_data")
name_enitity=nltk.ne_chunk(tag_elements)
print(name_enitity)
